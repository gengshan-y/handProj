# %%
####
# Filename:        genVideo.ipynb
# Date:            Jan 02 2017
# Last Edited by:  Gengshan Yang
# Description:     Generate videos of detection, tracking and pose estimation
#                  results. 
####

import os
import subprocess

def mvRes(imgPath, imgList, subDirName):
    """ move specified image results to given subfolder """
    dirName = os.path.join(imgPath, subDirName) 
    if os.path.exists(dirName):
        return
    else:
        os.makedirs(dirName)
        
    imgList = sorted(imgList)
    for it, name  in enumerate(imgList):
        a = os.path.join(imgPath, name)
        b = os.path.join(dirName, str(it).zfill(5) + ".jpg")
        os.rename(a, b)
        
def runFFMPEG(tbFilled):
    """ concat specified frames to a video, and clean subfloder """
    if os.path.exists('data/' + tbFilled + '.mp4'):
        return
    
    cmd = 'ffmpeg -f image2 -r 5 -i data/' + tbFilled + '/%05d.jpg -vcodec mpeg4 -y data/' + tbFilled + '.mp4'
    a = subprocess.check_output(cmd, shell=True, stderr=subprocess.STDOUT)
    print a
    
    """ remove image folder """
    cmd = 'rm -rf data/' + tbFilled
    a = subprocess.check_output(cmd, shell=True, stderr=subprocess.STDOUT)
    print a

# %%
imgPath = "/data/gengshan/handProj/"  # specify output frame path

# %%
""" get a list of image names """
imgList = os.listdir(imgPath)
detList = [x for x in imgList if ("det" in x) ]
trkList = [x for x in imgList if ("trk" in x) ]
posList = [x for x in imgList if ("pos" in x) ]
objPosList = {}
objIDs = list(set([x.split('_')[1] for x in posList]))
for ID in objIDs:
    objPosList[ID] = [x for x in posList if x.split('_')[1] == ID]

# %%
mvRes(imgPath, detList, 'det')
mvRes(imgPath, trkList, 'trk')
for ID, val in objPosList.items():
    mvRes(imgPath, val, 'pos_' + ID)

# %%
runFFMPEG('det')
runFFMPEG('trk')
for ID, val in objPosList.items():
    runFFMPEG('pos_' + ID)
# Out:
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x21159c0] Changing bps to 8
# Input #0, image2, from 'data/det/%05d.jpg':
#   Duration: 00:00:23.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x214cd00] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/det.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=  116 fps= 40 q=19.7 Lsize=     803kB time=00:00:23.20 bitrate= 283.4kbits/s
# video:801kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.165874%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x216a9c0] Changing bps to 8
# Input #0, image2, from 'data/trk/%05d.jpg':
#   Duration: 00:00:23.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x2243080] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/trk.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=  116 fps=9.0 q=25.8 Lsize=     889kB time=00:00:23.20 bitrate= 313.9kbits/s
# video:888kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.149734%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x1e3a9c0] Changing bps to 8
# Input #0, image2, from 'data/pos_10/%05d.jpg':
#   Duration: 00:00:09.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x20c5180] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_10.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   47 fps=0.0 q=13.9 Lsize=     645kB time=00:00:09.40 bitrate= 562.2kbits/s
# video:644kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.160877%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x2acf9c0] Changing bps to 8
# Input #0, image2, from 'data/pos_98/%05d.jpg':
#   Duration: 00:00:06.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x2afa6e0] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_98.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   31 fps=0.0 q=2.0 Lsize=     234kB time=00:00:06.20 bitrate= 309.8kbits/s
# video:234kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.415271%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x233b9c0] Changing bps to 8
# Input #0, image2, from 'data/pos_29/%05d.jpg':
#   Duration: 00:00:08.60, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x24cbf20] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_29.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   43 fps=0.0 q=2.0 Lsize=     418kB time=00:00:08.60 bitrate= 398.6kbits/s
# video:417kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.244481%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x28949c0] Changing bps to 8
# Input #0, image2, from 'data/pos_1/%05d.jpg':
#   Duration: 00:00:15.60, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x297bc20] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_1.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   78 fps=0.0 q=12.4 Lsize=     751kB time=00:00:15.60 bitrate= 394.5kbits/s
# video:750kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.155840%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x23e99c0] Changing bps to 8
# Input #0, image2, from 'data/pos_0/%05d.jpg':
#   Duration: 00:00:10.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x24c8a60] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_0.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   54 fps=0.0 q=8.1 Lsize=     660kB time=00:00:10.80 bitrate= 500.8kbits/s
# video:659kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.161928%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x2c729c0] Changing bps to 8
# Input #0, image2, from 'data/pos_122/%05d.jpg':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x2c9e120] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_122.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   20 fps=0.0 q=2.0 Lsize=     159kB time=00:00:04.00 bitrate= 324.8kbits/s
# video:158kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.585368%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x30e49c0] Changing bps to 8
# Input #0, image2, from 'data/pos_130/%05d.jpg':
#   Duration: 00:00:05.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x3105700] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_130.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   27 fps=0.0 q=2.0 Lsize=     273kB time=00:00:05.40 bitrate= 414.9kbits/s
# video:273kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.350119%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x1e5e9c0] Changing bps to 8
# Input #0, image2, from 'data/pos_124/%05d.jpg':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x1e89640] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_124.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   24 fps=0.0 q=2.0 Lsize=     172kB time=00:00:04.80 bitrate= 293.9kbits/s
# video:171kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.547884%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x2aae9c0] Changing bps to 8
# Input #0, image2, from 'data/pos_114/%05d.jpg':
#   Duration: 00:00:05.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x2ad6e80] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_114.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   29 fps=0.0 q=2.0 Lsize=     253kB time=00:00:05.80 bitrate= 356.7kbits/s
# video:252kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.382345%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x27e59c0] Changing bps to 8
# Input #0, image2, from 'data/pos_138/%05d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 5 fps, 5 tbr, 5 tbn, 5 tbc
# [swscaler @ 0x2818a40] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_138.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   12 fps=0.0 q=2.0 Lsize=      75kB time=00:00:02.40 bitrate= 257.4kbits/s
# video:75kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.191303%
