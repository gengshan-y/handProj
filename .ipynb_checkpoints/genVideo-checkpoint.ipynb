# %%
####
# Filename:        genVideo.ipynb
# Date:            Jan 02 2017
# Last Edited by:  Gengshan Yang
# Description:     Generate videos of detection, tracking and pose estimation
#                  results. 
####

import os
import subprocess

def mvRes(imgPath, imgList, subDirName):
    """ move specified image results to given subfolder """
    dirName = os.path.join(imgPath, subDirName) 
    if os.path.exists(dirName):
        return
    else:
        os.makedirs(dirName)
        
    imgList = sorted(imgList)
    for it, name  in enumerate(imgList):
        a = os.path.join(imgPath, name)
        b = os.path.join(dirName, str(it).zfill(5) + ".jpg")
        os.rename(a, b)
        
def runFFMPEG(tbFilled):
    """ concat specified frames to a video, and clean subfloder """
    cmd = 'ffmpeg -f image2 -r 20 -i data/' + tbFilled + '/%05d.jpg -vcodec mpeg4 -y data/' + tbFilled + '.mp4'
    a = subprocess.check_output(cmd, shell=True, stderr=subprocess.STDOUT)
    print a
    
    cmd = 'rm -rf data/' + tbFilled
    a = subprocess.check_output(cmd, shell=True, stderr=subprocess.STDOUT)
    print a

# %%
imgPath = "/data/gengshan/handProj/"  # specify output frame path

# %%
""" get a list of image names """
imgList = os.listdir(imgPath)
detList = [x for x in imgList if ("det" in x) ]
trkList = [x for x in imgList if ("trk" in x) ]
posList = [x for x in imgList if ("pos" in x) ]
objPosList = {}
objIDs = list(set([x.split('_')[1] for x in posList]))
for ID in objIDs:
    objPosList[ID] = [x for x in posList if x.split('_')[1] == ID]

# %%
mvRes(imgPath, detList, 'det')
mvRes(imgPath, trkList, 'trk')
for ID, val in objPosList.items():
    mvRes(imgPath, val, 'pos_' + ID)

# %%
runFFMPEG('det')
runFFMPEG('trk')
for ID, val in objPosList.items():
    runFFMPEG('pos_' + ID)
# Out:
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x2ce49c0] Changing bps to 8
# Input #0, image2, from 'data/det/%05d.jpg':
#   Duration: 00:00:03.25, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 640x480 [SAR 1:1 DAR 4:3], 20 fps, 20 tbr, 20 tbn, 20 tbc
# [swscaler @ 0x2d108c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/det.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 640x480 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 20 fps, 10240 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   65 fps=0.0 q=23.3 Lsize=     248kB time=00:00:03.25 bitrate= 626.1kbits/s
# video:247kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.450630%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x39229c0] Changing bps to 8
# Input #0, image2, from 'data/trk/%05d.jpg':
#   Duration: 00:00:03.25, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 640x480 [SAR 1:1 DAR 4:3], 20 fps, 20 tbr, 20 tbn, 20 tbc
# [swscaler @ 0x394de80] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/trk.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 640x480 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 20 fps, 10240 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   65 fps=0.0 q=16.5 Lsize=     293kB time=00:00:03.25 bitrate= 737.7kbits/s
# video:292kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.382178%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x37589c0] Changing bps to 8
# Input #0, image2, from 'data/pos_55/%05d.jpg':
#   Duration: 00:00:00.25, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 640x480 [SAR 1:1 DAR 4:3], 20 fps, 20 tbr, 20 tbn, 20 tbc
# [swscaler @ 0x37774e0] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_55.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 640x480 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 20 fps, 10240 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=    5 fps=0.0 q=2.0 Lsize=      34kB time=00:00:00.25 bitrate=1129.0kbits/s
# video:34kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.561121%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x30f79c0] Changing bps to 8
# Input #0, image2, from 'data/pos_0/%05d.jpg':
#   Duration: 00:00:03.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 640x480 [SAR 1:1 DAR 4:3], 20 fps, 20 tbr, 20 tbn, 20 tbc
# [swscaler @ 0x31215a0] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_0.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 640x480 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 20 fps, 10240 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   64 fps=0.0 q=12.9 Lsize=     312kB time=00:00:03.20 bitrate= 800.0kbits/s
# video:311kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.356600%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x2e8c9c0] Changing bps to 8
# Input #0, image2, from 'data/pos_45/%05d.jpg':
#   Duration: 00:00:01.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 640x480 [SAR 1:1 DAR 4:3], 20 fps, 20 tbr, 20 tbn, 20 tbc
# [swscaler @ 0x2eaede0] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_45.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 640x480 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 20 fps, 10240 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   20 fps=0.0 q=2.0 Lsize=     105kB time=00:00:01.00 bitrate= 863.7kbits/s
# video:105kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.883013%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x302c9c0] Changing bps to 8
# Input #0, image2, from 'data/pos_20/%05d.jpg':
#   Duration: 00:00:01.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 640x480 [SAR 1:1 DAR 4:3], 20 fps, 20 tbr, 20 tbn, 20 tbc
# [swscaler @ 0x30536c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_20.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 640x480 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 20 fps, 10240 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   20 fps=0.0 q=2.0 Lsize=     126kB time=00:00:01.00 bitrate=1028.2kbits/s
# video:125kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.740677%
#
#
# ffmpeg version N-77182-gbd3409f Copyright (c) 2000-2015 the FFmpeg developers
#   built with gcc 4.8 (Ubuntu 4.8.4-2ubuntu1~14.04)
#   configuration:
#   libavutil      55. 10.100 / 55. 10.100
#   libavcodec     57. 17.100 / 57. 17.100
#   libavformat    57. 19.100 / 57. 19.100
#   libavdevice    57.  0.100 / 57.  0.100
#   libavfilter     6. 20.100 /  6. 20.100
#   libswscale      4.  0.100 /  4.  0.100
#   libswresample   2.  0.101 /  2.  0.101
# [mjpeg @ 0x371d9c0] Changing bps to 8
# Input #0, image2, from 'data/pos_25/%05d.jpg':
#   Duration: 00:00:01.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 640x480 [SAR 1:1 DAR 4:3], 20 fps, 20 tbr, 20 tbn, 20 tbc
# [swscaler @ 0x373eec0] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp4, to 'data/pos_25.mp4':
#   Metadata:
#     encoder         : Lavf57.19.100
#     Stream #0:0: Video: mpeg4 ( [0][0][0] / 0x0020), yuv420p, 640x480 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 20 fps, 10240 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc57.17.100 mpeg4
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# frame=   20 fps=0.0 q=2.0 Lsize=     101kB time=00:00:01.00 bitrate= 823.8kbits/s
# video:100kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.926225%
